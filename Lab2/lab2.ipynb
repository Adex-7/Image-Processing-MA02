# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
def sample_image(image, factor):
    """
    Downsamples the image by the given factor.
    Args:
        image (numpy array): Original image.
        factor (int): Factor by which to downsample.
    Returns:
        numpy array: Downsampled image.
    """
    height, width = image.shape[:2]
    sampled_image = cv2.resize(image, (width // factor, height // factor), interpolation=cv2.INTER_NEAREST)
    return sampled_image

def quantize_image(image, levels):
    """
    Reduces the number of grayscale levels in the image.
    Args:
        image (numpy array): Original image.
        levels (int): Number of grayscale levels.
    Returns:
        numpy array: Quantized image.
    """
    quantized_image = np.floor(image / (256 // levels)) * (256 // levels)
    quantized_image = quantized_image.astype(np.uint8)
    return quantized_image

def plot_images(original, sampled, quantized):
    """
    Plots the original, sampled, and quantized images side by side.
    Args:
        original (numpy array): Original image.
        sampled (numpy array): Sampled image.
        quantized (numpy array): Quantized image.
    """
    plt.figure(figsize=(12, 4))
    plt.subplot(1, 3, 1)
    plt.imshow(original, cmap='gray')
    plt.title('Original Image')
    plt.axis('off')

    plt.subplot(1, 3, 2)
    plt.imshow(sampled, cmap='gray')
    plt.title('Sampled Image')
    plt.axis('off')

    plt.subplot(1, 3, 3)
    plt.imshow(quantized, cmap='gray')
    plt.title('Quantized Image')
    plt.axis('off')

    plt.show()

# %%
import os
print(os.getcwd())
# Out:
# c:\Users\xisni\py\imgpros\Lab2

# %%
image_path='c:/Users/xisni/py/imgpros/Lab2/bnw.png'
sampling_factor=20
quantization_levels=5

# Load image in grayscale
original_image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)
if original_image is None:
    print(f"Error: Unable to load image at {image_path}")

# Sample and quantize
sampled_image = sample_image(original_image, sampling_factor)
quantized_image = quantize_image(original_image, quantization_levels)

# Plot results
plot_images(original_image, sampled_image, quantized_image)

# %%
#Arithmetic Operations

from PIL import Image
img1=Image.open('c:/Users/xisni/py/imgpros/Lab2/dog.jpg')
img2=Image.open ('c:/Users/xisni/py/imgpros/Lab2/imagesample.jpg')

resize=(400,400)
img1=img1.resize(resize,Image.Resampling.LANCZOS)
img2=img2.resize(resize,Image.Resampling.LANCZOS)

im1arr=np.asarray(img1)
im2arr=np.asarray(img2)

addition=im1arr+im2arr
resultImage=Image.fromarray(addition)
resultImage.show()

#Sets and Logical Operations

img3=Image.open('c:/Users/xisni/py/imgpros/Lab2/imagesample.jpg')
img3.show()
img4=Image.open('c:/Users/xisni/py/imgpros/Lab2/flower.jpg')
img4.show()

resize=(400,400)
img3=img3.resize(resize,Image.Resampling.LANCZOS)
img4=img4.resize(resize,Image.Resampling.LANCZOS)

im3arr=np.asarray(img3)
im4arr=np.asarray(img4)

union=im4arr|im3arr
resultImage2=Image.fromarray(union)
resultImage2.show()

# %%
#Task2:

#1.	Subtract two images and display the result
from PIL import Image
img1=Image.open('c:/Users/xisni/py/imgpros/Lab2/dog.jpg')
img2=Image.open ('c:/Users/xisni/py/imgpros/Lab2/imagesample.jpg')

resize=(400,400)
img1=img1.resize(resize,Image.Resampling.LANCZOS)
img2=img2.resize(resize,Image.Resampling.LANCZOS)

im1arr=np.asarray(img1)
im2arr=np.asarray(img2)

addition=im1arr-im2arr
resultImage=Image.fromarray(addition)
resultImage.show()

# %%
#2.	Add one image with a constant value of 175 and display it

img1 = Image.open('c:/Users/xisni/py/imgpros/Lab2/dog.jpg')
resize = (400, 400)
img1 = img1.resize(resize, Image.Resampling.LANCZOS)

im1arr = np.asarray(img1, dtype=np.int16)

# Add constant value 175
constant175 = im1arr + 175

# Clip values to valid range [0, 255]
constant175 = np.clip(constant175, 0, 255).astype(np.uint8)
resultImage = Image.fromarray(constant175)
resultImage.show()


#3.	Apply the set difference operation on two Gray-Scale images. 

img1 = Image.open('c:/Users/xisni/py/imgpros/Lab2/dog.jpg').convert('L')
img2 = Image.open('c:/Users/xisni/py/imgpros/Lab2/imagesample.jpg').convert('L')

resize = (400, 400)
img1 = img1.resize(resize, Image.Resampling.LANCZOS)
img2 = img2.resize(resize, Image.Resampling.LANCZOS)
im1arr = np.asarray(img1, dtype=np.uint8)
im2arr = np.asarray(img2, dtype=np.uint8)

set_difference = np.where(im1arr != im2arr, im1arr, 0)

set_diff_img = Image.fromarray(set_difference)
set_diff_img.show()
symmetric_difference = np.bitwise_xor(im1arr, im2arr)

#4.	Apply the symmetric difference operation on two Gray-Scale images. 
sym_diff_img = Image.fromarray(symmetric_difference)
sym_diff_img.show()
intersection = np.bitwise_and(im1arr, im2arr)
#5.	Apply Intersection operations on two Gray-Scale images. 
intersection_img = Image.fromarray(intersection)
intersection_img.show()
